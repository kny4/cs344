# %% [markdown]
# # Models for Sequence Data
#
# The goal of this exercise is to explore the structure, speed, and data flow in each of the 4 main kinds of models that are often used for sequence data: feedforward, recurrent (LSTM/GRU), convolutional, and self-attention (Transformer).
#
# This level of knowledge of how each model works should equip you to make wise decisions about when to use each one, without having to get too much into the details of how each one works.

# %% [markdown]
# ## Setup

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

def highlight_values(x):
    """Show a 2D tensor with background highlighted. Also show the norms."""
    x = x.squeeze() # collapse singleton dimensions, like batch.
    assert len(x.shape) == 2, "Can only handle 2D data"
    display(pd.DataFrame(x.numpy()).style.background_gradient(axis=None))
    plt.plot(x.norm(dim=1)); plt.title("Norm on axis 1"); plt.xlabel("Input time step")

def num_parameters(model):
    """Count the number of trainable parameters in a model"""
    return sum(param.numel() for param in model.parameters() if param.requires_grad)

def time_trial(model, embeddings, concat_on_axis=1):
    '''Time how long a forward pass of the model takes on embeddings, varying the sequence length.'''
    for i in range(5):
        num_reps = 2 ** i
        x = torch.cat([embeddings] * num_reps, axis=concat_on_axis)
        print(f'{num_reps} repetitions of the original sequence, shape = {tuple(x.shape)}')
        # %timeit -r 3 model(x)

# %% [markdown]
# ## Getting started
#
# Let's start with an input sequence.

# %%
sentence = "The quick brown fox jumped over the lazy dogs."

# %% [markdown]
# Let's turn it into numbers by using the Unicode code point for each character. We'll make a "batch" of one sequence.

# %%
sentence_tensor = torch.tensor([[ord(x) for x in sentence]])
sentence_tensor
# Out:
# tensor([[ 84, 104, 101,  32, 113, 117, 105,  99, 107,  32,  98, 114, 111, 119,
#          110,  32, 102, 111, 120,  32, 106, 117, 109, 112, 101, 100,  32, 111,
#          118, 101, 114,  32, 116, 104, 101,  32, 108,  97, 122, 121,  32, 100,
#          111, 103, 115,  46]])

# %%
def decode(x):
    return ''.join(chr(x) for x in x.numpy())
decode(sentence_tensor[0])
# Out:
# 'The quick brown fox jumped over the lazy dogs.'

# %% [markdown]
# We'll make this an autoregressive language model, so our goal will be to predict the next character. So we'll need to shift the targets left, so each character should output the next one.

# %%
targets = sentence_tensor[:, 1:]
input_ids = sentence_tensor[:, :-1]
assert input_ids.shape == targets.shape

# %% [markdown]
# Now let's make those numbers into vectors using an embedding. Note that we're just going to use the random initialization right now; we're not yet training this model.

# %%
n_vocab = 256
emb_dim = 5
embedder = nn.Embedding(n_vocab, emb_dim)
embedder.weight.shape
# Out:
# torch.Size([256, 5])

# %%
num_parameters(embedder)
# Out:
# 1280

# %% [markdown]
# Now we compute the embeddings for our string. **Make sure you can explain the shape of this result.**

# %%
embeddings = embedder(input_ids)
embeddings.shape
# Out:
# torch.Size([1, 45, 5])

# %% [markdown]
# Now we'll define the linear layer that goes from embeddings back to words. This is usually called the "language modeling head". We'll *tie the weights* of the LM head with the embedding layer, saving some parameters.

# %%
lm_head = nn.Linear(emb_dim, n_vocab)
assert lm_head.weight.shape == embedder.weight.shape
lm_head.weight = embedder.weight

# %% [markdown]
# Here's what the output of the model will look like. We haven't trained anything yet, though, so the specific numbers will be garbage, but the shape is right and that's most of the battle.

# %%
x = embeddings # pretend that this is the model...
logits = lm_head(x)
logits.shape
# Out:
# torch.Size([1, 45, 256])

# %% [markdown]
# Then we'll compute the cross-entropy loss as usual.
#
# Note: we need to `transpose` the `logits` so that the time steps are on the last dimension, so the last dimensions line up with `targets`. I suspect PyTorch uses this convention because it could extend to 2D `targets` (e.g., images), but I admit I'm not entirely sure why.

# %%
loss = F.cross_entropy(logits.transpose(1, 2), targets, reduction='none')
loss.shape
# Out:
# torch.Size([1, 45])

# %% [markdown]
# ## Feed-Forward Network

# %% [markdown]
# Here's the simplest model we can make: a multi-layer perceptron. Fill in the blanks here so our model has *one hidden layer* with a *relu activation* (`nn.ReLU`).
#
# - The output should have the same dimensionality as the embeddings
# - Set `n_hidden` to a small integer, so that there are about 180 parameters.

# %% [markdown]
# ### Create the model

# %%
n_hidden = 16 #increased starting at 10
mlp = nn.Sequential(
    nn.Linear(in_features=emb_dim, out_features=n_hidden),
    nn.ReLU(),
    nn.Linear(in_features=n_hidden, out_features=emb_dim)
)

num_parameters(mlp)
# Out:
# 181

# %% [markdown]
# ### Check its output shape

# %%
output = mlp(embeddings)
assert output.shape == (1, 45, 5)
output.shape
# Out:
# torch.Size([1, 45, 5])

# %% [markdown]
# ### Check its speed

# %%
time_trial(mlp, embeddings)
# Out:
# 1 repetitions of the original sequence, shape = (1, 45, 5)
# 29.1 µs ± 48.9 ns per loop (mean ± std. dev. of 3 runs, 10000 loops each)
# 2 repetitions of the original sequence, shape = (1, 90, 5)
# 29.9 µs ± 33.7 ns per loop (mean ± std. dev. of 3 runs, 10000 loops each)
# 4 repetitions of the original sequence, shape = (1, 180, 5)
# 31.6 µs ± 18.7 ns per loop (mean ± std. dev. of 3 runs, 10000 loops each)
# 8 repetitions of the original sequence, shape = (1, 360, 5)
# 35.9 µs ± 109 ns per loop (mean ± std. dev. of 3 runs, 10000 loops each)
# 16 repetitions of the original sequence, shape = (1, 720, 5)
# 43.9 µs ± 392 ns per loop (mean ± std. dev. of 3 runs, 10000 loops each)

# %% [markdown]
# ### Check how gradients flow

# %%
# Recreate the embeddings
embeddings = embedder(input_ids)
embeddings.retain_grad() # Tell Torch we want to know what the gradients are here.
# Pass the embeddings through the model and language modeling head.
output = mlp(embeddings)
logits = lm_head(output)
# Compute the loss
loss = F.cross_entropy(logits.transpose(1, 2), targets, reduction='none')
# Let the model learn from one single character (the one at index 20)
loss[0, 20].backward()
# Show the results
highlight_values(embeddings.grad)
# Out:
# <style type="text/css">
# #T_035b8_row0_col0, #T_035b8_row0_col1, #T_035b8_row0_col2, #T_035b8_row0_col3, #T_035b8_row0_col4, #T_035b8_row1_col0, #T_035b8_row1_col1, #T_035b8_row1_col2, #T_035b8_row1_col3, #T_035b8_row1_col4, #T_035b8_row2_col0, #T_035b8_row2_col1, #T_035b8_row2_col2, #T_035b8_row2_col3, #T_035b8_row2_col4, #T_035b8_row3_col0, #T_035b8_row3_col1, #T_035b8_row3_col2, #T_035b8_row3_col3, #T_035b8_row3_col4, #T_035b8_row4_col0, #T_035b8_row4_col1, #T_035b8_row4_col2, #T_035b8_row4_col3, #T_035b8_row4_col4, #T_035b8_row5_col0, #T_035b8_row5_col1, #T_035b8_row5_col2, #T_035b8_row5_col3, #T_035b8_row5_col4, #T_035b8_row6_col0, #T_035b8_row6_col1, #T_035b8_row6_col2, #T_035b8_row6_col3, #T_035b8_row6_col4, #T_035b8_row7_col0, #T_035b8_row7_col1, #T_035b8_row7_col2, #T_035b8_row7_col3, #T_035b8_row7_col4, #T_035b8_row8_col0, #T_035b8_row8_col1, #T_035b8_row8_col2, #T_035b8_row8_col3, #T_035b8_row8_col4, #T_035b8_row9_col0, #T_035b8_row9_col1, #T_035b8_row9_
33_col3, #T_035b8_row33_col4, #T_035b8_row34_col0, #T_035b8_row34_col1, #T_035b8_row34_col2, #T_035b8_row34_col3, #T_035b8_row34_col4, #T_035b8_row35_col0, #T_035b8_row35_col1, #T_035b8_row35_col2, #T_035b8_row35_col3, #T_035b8_row35_col4, #T_035b8_row36_col0, #T_035b8_row36_col1, #T_035b8_row36_col2, #T_035b8_row36_col3, #T_035b8_row36_col4, #T_035b8_row37_col0, #T_035b8_row37_col1, #T_035b8_row37_col2, #T_035b8_row37_col3, #T_035b8_row37_col4, #T_035b8_row38_col0, #T_035b8_row38_col1, #T_035b8_row38_col2, #T_035b8_row38_col3, #T_035b8_row38_col4, #T_035b8_row39_col0, #T_035b8_row39_col1, #T_035b8_row39_col ...
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_035b8_row20_col0 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_035b8_row20_col1 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_035b8_row20_col2 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_035b8_row20_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_035b8_row20_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_035b8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_035b8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_035b8_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_035b8_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_035b8_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_035b8_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_035b8_row0_col4" class="data row0 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_035b8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_035b8_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_035b8_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_035b8_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_035b8_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_035b8_row1_col4" class="data row1 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_035b8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_035b8_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_035b8_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_035b8_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_035b8_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_035b8_row2_col4" class="data row2 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_035b8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_035b8_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_035b8_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_035b8_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_035b8_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_035b8_row3_col4" class="data row3 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_035b8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_035b8_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_035b8_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_035b8_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_035b8_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_035b8_row4_col4" class="data row4 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_035b8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_035b8_row5_col0" class="data row5 col0" >0.000000</td>
#       <td id="T_035b8_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_035b8_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_035b8_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id=

# %% [markdown]
# ## GRU

# %%
gru = nn.GRU(emb_dim, emb_dim, batch_first=True)
num_parameters(gru)
# Out:
# 180

# %%
output, hidden = gru(embeddings)
output.shape, hidden.shape
# Out:
# (torch.Size([1, 45, 5]), torch.Size([1, 1, 5]))

# %% [markdown]
# Note that `hidden` is just another name for the output at the last state (since GRU is simple).

# %%
(output[:, -1, :] == hidden).all()
# Out:
# tensor(True)

# %% [markdown]
# ### Your turn
#
# 1. Repeat the time trial, but for `gru` this time.

# %%
time_trial(gru, embeddings)
# Out:
# 1 repetitions of the original sequence, shape = (1, 45, 5)
# 1.14 ms ± 3.09 µs per loop (mean ± std. dev. of 3 runs, 1000 loops each)
# 2 repetitions of the original sequence, shape = (1, 90, 5)
# 2.18 ms ± 4 µs per loop (mean ± std. dev. of 3 runs, 100 loops each)
# 4 repetitions of the original sequence, shape = (1, 180, 5)
# 4.28 ms ± 6.32 µs per loop (mean ± std. dev. of 3 runs, 100 loops each)
# 8 repetitions of the original sequence, shape = (1, 360, 5)
# 8.66 ms ± 42.7 µs per loop (mean ± std. dev. of 3 runs, 100 loops each)
# 16 repetitions of the original sequence, shape = (1, 720, 5)
# 17.9 ms ± 307 µs per loop (mean ± std. dev. of 3 runs, 100 loops each)

# %% [markdown]
# 2. Repeat the gradient-flow experiment by copy-pasting the code above and changing the model. Remember that `gru` returns `output, hidden`, unlike the other models.

# %%
# Recreate the embeddings
embeddings = embedder(input_ids)
embeddings.retain_grad() # Tell Torch we want to know what the gradients are here.
# Pass the embeddings through the model and language modeling head.
output, hidden = gru(embeddings)
logits = lm_head(output)
# Compute the loss
loss = F.cross_entropy(logits.transpose(1, 2), targets, reduction='none')
# Let the model learn from one single character (the one at index 20)
loss[0, 20].backward()
# Show the results
highlight_values(embeddings.grad)
# Out:
# <style type="text/css">
# #T_19ed2_row0_col0, #T_19ed2_row0_col1, #T_19ed2_row0_col2, #T_19ed2_row0_col3, #T_19ed2_row0_col4, #T_19ed2_row1_col0, #T_19ed2_row1_col1, #T_19ed2_row1_col2, #T_19ed2_row1_col3, #T_19ed2_row1_col4, #T_19ed2_row2_col0, #T_19ed2_row2_col1, #T_19ed2_row2_col2, #T_19ed2_row2_col3, #T_19ed2_row2_col4, #T_19ed2_row3_col0, #T_19ed2_row3_col1, #T_19ed2_row3_col2, #T_19ed2_row3_col3, #T_19ed2_row4_col0, #T_19ed2_row4_col
2_row38_col3, #T_19ed2_row38_col4, #T_19ed2_row39_col0, #T_19ed2_row39_col1, #T_19ed2_row39_col2, #T_19ed2_row39_col3, #T_19ed2_row39_col4, #T_19ed2_row40_col0, #T_19ed2_row40_col1, #T_19ed2_row40_col2, #T_19ed2_row40_col3, #T_19ed2_row40_col4, #T_19ed2_row41_col0, #T_19ed2_row41_col1, #T_19ed2_row41_col2, #T_19ed2_row41_col3, #T_19ed2_row41_col4, #T_19ed2_row42_col0, #T_19ed2_row42_col1, #T_19ed2_row42_col2, #T_19ed2_row42_col3, #T_19ed2_row42_col4, #T_19ed2_row43_col0, #T_19ed2_row43_col1, #T_19ed2_row43_col2, #T_19ed2_row43_col3, #T_19ed2_row43_col4, #T_19ed2_row44_col0, #T_19ed2_row44_col1, #T_19ed2_row44_col2, #T_19ed2_row44_col3, #T_19ed2_row44_col4 {
#   background-color: #056ba9;
#   color: #f1f1f1;
# }
# #T_19ed2_row3_col4, #T_19ed2_row5_col4, #T_19ed2_row6_col4, #T_19ed2_row7_col1, #T_19ed2_row7_col4, #T_19ed2_row8_col1, #T_19ed2_row8_col2, #T_19ed2_row8_col3, #T_19ed2_row8_col4, #T_19ed2_row9_col1, #T_19ed2_row9_col2, #T_19ed2_row9_col3, #T_19ed2_row10_col1, #T_19ed2_row10_col2, #T_19ed2_row10_col3, #T_19ed2_row11_col2, #T_19ed2_row11_col3, #T_19ed2_row15_col0, #T_19ed2_row18_col3 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_19ed2_row9_col4, #T_19ed2_row10_col4, #T_19ed2_row11_col1, #T_19ed2_row11_col4, #T_19ed2_row12_col1, #T_19ed2_row12_col2, #T_19ed2_row12_col3, #T_19ed2_row14_col0, #T_19ed2_row18_col1 {
#   background-color: #056dab;
#   color: #f1f1f1;
# }
# #T_19ed2_row12_col4, #T_19ed2_row20_col2 {
#   background-color: #056ead;
#   color: #f1f1f1;
# }
# #T_19ed2_row13_col0 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_19ed2_row13_col1, #T_19ed2_row13_col2 {
#   background-color: #056dac;
#   color: #f1f1f1;
# }
# #T_19ed2_row13_col3 {
#   background-color: #056fae;
#   color: #f1f1f1;
# }
# #T_19ed2_row13_col4, #T_19ed2_row14_col2 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_19ed2_row14_col1 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_19ed2_row14_col3 {
#   background-color: #0d75b3;
#   color: #f1f1f1;
# }
# #T_19ed2_row14_col4 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_19ed2_row15_col1 {
#   background-color: #0a73b2;
#   color: #f1f1f1;
# }
# #T_19ed2_row15_col2 {
#   background-color: #0f76b3;
#   color: #f1f1f1;
# }
# #T_19ed2_row15_col3 {
#   background-color: #157ab5;
#   color: #f1f1f1;
# }
# #T_19ed2_row15_col4 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_19ed2_row16_col0, #T_19ed2_row17_col1, #T_19ed2_row18_col2 {
#   background-color: #1278b4;
#   color: #f1f1f1;
# }
# #T_19ed2_row16_col1 {
#   background-color: #167bb6;
#   color: #f1f1f1;
# }
# #T_19ed2_row16_col2 {
#   background-color: #197db7;
#   color: #f1f1f1;
# }
# #T_19ed2_row16_col3 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_19ed2_row16_col4 {
#   background-color: #4496c3;
#   color: #f1f1f1;
# }
# #T_19ed2_row17_col0, #T_19ed2_row17_col3 {
#   background-color: #2484ba;
#   color: #f1f1f1;
# }
# #T_19ed2_row17_col2 {
#   background-color: #2987bc;
#   color: #f1f1f1;
# }
# #T_19ed2_row17_col4 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_19ed2_row18_col0 {
#   background-color: #2c89bd;
#   color: #f1f1f1;
# }
# #T_19ed2_row18_col4 {
#   background-color: #529bc7;
#   color: #f1f1f1;
# }
# #T_19ed2_row19_col0 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_19ed2_row19_col1 {
#   background-color: #2081b9;
#   color: #f1f1f1;
# }
# #T_19ed2_row19_col2 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_19ed2_row19_col3 {
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_19ed2_row19_col4 {
#   background-color: #d3d4e7;
#   color: #000000;
# }
# #T_19ed2_row20_col0 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_19ed2_row20_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_19ed2_row20_col3 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_19ed2_row20_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_19ed2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_19ed2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_19ed2_row0_col0" class="data row0 col0" >0.000002</td>
#       <td id="T_19ed2_row0_col1" class="data row0 col1" >-0.000006</td>
#       <td id="T_19ed2_row0_col2" class="data row0 col2" >-0.000006</td>
#       <td id="T_19ed2_row0_col3" class="data row0 col3" >-0.000007</td>
#       <td id="T_19ed2_row0_col4" class="data row0 col4" >-0.000012</td>
#     </tr>
#     <tr>
#       <th id="T_19ed2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_19ed2_row1_col0" class="data row1 col0" >0.000010</td>
#       <td id="T_19ed2_row1_col1" class="data row1 col1" >-0.000003</td>
#       <td id="T_19ed2_row1_col2" class="data row1 col2" >-0.000007</td>
#       <td id="T_19ed2_row1_col3" class="data row1 col3" >-0.000014</td>
#       <td id="T_19ed2_row1_col4" class="data row1 col4" >-0.000021</td>
#     </tr>
#     <tr>
#       <th id="T_19ed2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_19ed2_row2_col0" class="data row2 col0" >0.000015</td>
#       <td id="T_19ed2_row2_col1" class="data row2 col1" >-0.000007</td>
#       <td id="T_19ed2_row2_col2" class="data row2 col2" >-0.000012</td>
#       <td id="T_19ed2

# %% [markdown]
# ## Convolution

# %% [markdown]
# Now let's make a convolutional network. We'll pick a "kernel size" (how wide a window for each sample to look) so that the total number of parameters matches our previous models. We also need to pad the result so that the output length is the same as the input length; the outputs near the edges won't be valid outputs, though.

# %%
conv = nn.Conv1d(emb_dim, emb_dim, kernel_size=7, padding=3)
num_parameters(conv)
# Out:
# 180

# %% [markdown]
# Unfortunately Conv expects its inputs to be (batch size, *channel*, sequence length), where they think of embedding dimensions as being "channels" -- confusing. Fortunately, this is easily solved by a `transpose` before and after the conv. (not to be confused with "transposed convolution", which is something different.)

# %%
embeddings_for_conv = embeddings.transpose(1, 2)
embeddings_for_conv.shape
# Out:
# torch.Size([1, 5, 45])

# %%
output = conv(embeddings.transpose(1, 2)).transpose(1, 2)
output.shape
# Out:
# torch.Size([1, 45, 5])

# %% [markdown]
# The fact that we had to transpose the embeddings means that we need to tweak `time_trial` to tell it which dimension is the sequence dimension.

# %%
time_trial(conv, embeddings_for_conv, concat_on_axis=2)
# Out:
# 1 repetitions of the original sequence, shape = (1, 5, 45)
# 19.3 µs ± 66.6 ns per loop (mean ± std. dev. of 3 runs, 100000 loops each)
# 2 repetitions of the original sequence, shape = (1, 5, 90)
# 20.2 µs ± 183 ns per loop (mean ± std. dev. of 3 runs, 10000 loops each)
# 4 repetitions of the original sequence, shape = (1, 5, 180)
# 20.7 µs ± 75.2 ns per loop (mean ± std. dev. of 3 runs, 10000 loops each)
# 8 repetitions of the original sequence, shape = (1, 5, 360)
# 22.7 µs ± 118 ns per loop (mean ± std. dev. of 3 runs, 10000 loops each)
# 16 repetitions of the original sequence, shape = (1, 5, 720)
# 26.2 µs ± 34 ns per loop (mean ± std. dev. of 3 runs, 10000 loops each)

# %% [markdown]
# **Your turn**: Repeat the gradient-flow experiment. Make sure you compute `output` as we did above so that the shape is correct.

# %%
# Recreate the embeddings
embeddings = embedder(input_ids)
embeddings.retain_grad() # Tell Torch we want to know what the gradients are here.
# Pass the embeddings through the model and language modeling head.
output = conv(embeddings.transpose(1,2)).transpose(1,2)
logits = lm_head(output)
# Compute the loss
loss = F.cross_entropy(logits.transpose(1, 2), targets, reduction='none')
# Let the model learn from one single character (the one at index 20)
loss[0, 20].backward()
# Show the results
highlight_values(embeddings.grad)
# Out:
# <style type="text/css">
# #T_860f8_row0_col0, #T_860f8_row0_col1, #T_860f8_row0_col2, #T_860f8_row0_col3, #T_860f8_row0_col4, #T_860f8_row1_col0, #T_860f8_row1_col1, #T_860f8_row1_col2, #T_860f8_row1_col3, #T_860f8_row1_col4, #T_860f8_row2_col0, #T_860f8_row2_col1, #T_860f8_row2_col2, #T_860f8_row2_col3, #T_860f8_row2_col4, #T_860f8_row3_col0, #T_860f8_row3_col1, #T_860f8_row3_col2, #T_860f8_row3_col3, #T_860f8_row3_col4, #T_860f8_row4_col0, #T_860f8_row4_col1, #T_860f8_row4_col2, #T_860f8_row4_col3, #T_860f8_row4_col4, #T_860f8_row5_col0, #T_860f8_row5_col1, #T_860f8_row5_col2, #T_860f8_row5_col3, #T_860f8_row5_col4, #T_860f8_row6_col0, #T_860f8_row6_col1, #T_860f8_row6_col2, #T_860f8_row6_col3, #T_860f8_row6_col4, #T_860f8_row7_col0, #T_860f8_row7_col1, #T_860f8_row7_col2, #T_860f8_row7_col3, #T_860f8_row7_col4, #T_860f8_row8_col0, #T_860f8_row8_col1, #T_860f8_row8_col2, #T_860f8_row8_col3, #T_860f8_row8_col4, #T_860f8_row9_col0, #T_860f8_row9_col1, #T_860f8_row9_col2, #T_860f8_row9_col3, #T_860f8_row9_col4, #T_860f8_row10_col0, #T_860f8_row10_col1, #T_860f8_row10_col2, #T_860f8_row10_col3, #T_860f8_row10_col4, #T_860f8_row11_col0, #T_860f8_row11_col1, #T_860f8_row11_col2, #T_860f8_row11_col3, #T_860f8_row11_col4, #T_860f8_row12_col0, #T_860f8_row12_col1, #T_860f8_row12_col2, #T_860f8_row12_col3, #T_860f8_row12_col4, #T_860f8_row13_col0, #T_860f8_row13_col1, #T_860f8_row13_col2, #T_860f8_row13_col3, #T_860f8_row13_col4, #T_860f8_row14_col0, #T_860f8_row14_col1, #T_860f8_row14_col2, #T_860f8_row14_col3, #T_860f8_row14_col4, #T_860f8_row15_col0, #T_860f8_row15_col1, #T_860f8_row15_col2, #T_860f8_row15_col3, #T_860f8_row15_col4, #T_860f8_row16_col0, #T_860f8_row16_col1, #T_860f8_row16_col2, #T_860f8_row16_col3, #T_860f8_row16_col4, #T_860f8_row24_col0, #T_860f8_row24_col1, #T_860f8_row24_col2, #T_860f8_row24_col3, #T_860f8_row24_col4, #T_860f8_row25_col0, #T_860f8_row25_col1, #T_860f8_row25_col2, #T_860f8_row25_col3, #T_860f8_row25_col4, #T_860f8_row26_col0, #T_860f8_row26_col1, #T_860f8_row26_col2, #T_860f8_row26_col3, #T_860f8_row26_col4, #T_860f8_row27_col0, #T_860f8_row27_col1, #T_860f8_row27_col2, #T_860f8_row27_col3, #T_860f8_row27_col4, #T_860f8_row28_col0, #T_860f8_row28_col1, #T_860f8_row28_col2, #T_860f8_row28_col3, #T_860f8_row28_col4, #T_860f8_row29_col0, #T_860f8_row29_col1, #T_860f8_row29_col2, #T_860f8_row29_col3, #T_860f8_row29_col4, #T_860f8_row30_col0, #T_860f8_row30_col1, #T_860f8_row30_col2, #T_860f8_row30_col3, #T_860f8_row30_col4, #T_860f8_row31_col0, #T_860f8_row31_col1, #T_860f8_row31_col2, #T_860f8_row31_col3, #T_860f8_row31_col4, #T_860f8_row32_col0, #T_860f8_row32_col1, #T_860f8_row32_col2, #T_860f8_row32_col3, #T_860f8_row32_col4, #T_860f8_row33_col0, #T_860f8_row33_col1, #T_860f8_row33_col2, #T_860f8_row33_col3, #T_860f8_row33_col4, #T_860f8_row34_col0, #T_860f8_row34_col1, #T_860f8_row34_col2, #T_860f8_row34_col3, #T_860f8_row34_col4, #T_860f8_row35_col0, #T_860f8_row35_col1, #T_860f8_row35_col2, #T_860f8_row35_col3, #T_860f8_row35_col4, #T_860f8_row36_col0, #T_860f8_row36_col1, #T_860f8_row36_col2, #T_860f8_row36_col3, #T_860f8_row36_col4, #T_860f8_row37_col0, #T_860f8_row37_col1, #T_860f8_row37_col2, #T_860f8_row37_col3, #T_860f8_row37_col4, #T_860f8_row38_col0, #T_860f8_row38_col1, #T_860f8_row38_col2, #T_860f8_row38_col3, #T_860f8_row38_col4, #T_860f8_row39_col0, #T_860f8_row39_col1, #T_860f8_row39_col2, #T_860f8_row39_col3, #T_860f8_row39_col4, #T_860f8_row40_col0, #T_860f8_row40_col1, #T_860f8_row40_col2, #T_860f8_row40_col3, #T_860f8_row40_col4, #T_860f8_row41_col0, #T_860f8_row41_col1, #T_860f8_row41_col2, #T_860f8_row41_col3, #T_860f8_row41_col4, #T_860f8_row42_col0, #T_860f8_row42_col1, #T_860f8_row42_col2, #T_860f8_row42_col3, #T_860f8_row42_col4, #T_860f8_row43_col0, #T_860f8_row43_col1, #T_860f8_row43_col2, #T_860f8_row43_col3, #T_860f8_row43_col4, #T_860f8_row44_col0, #T_860f8_row44_col1, #T_860f8_row44_col2, #T_860f8_row44_col3, #T_860f8_row44_col4 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_860f8_row17_col0 {
#   background-color: #bfc9e1;
#   color: #000000;
# }
# #T_860f8_row17_col1 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_860f8_row17_col2 {
#   background-color: #348ebf;
#   color: #f1f1f1;
# }
# #T_860f8_row17_col3 {
#   background-color: #84b0d3;
#   color: #f1f1f1;
# }
# #T_860f8_row17_col4 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_860f8_row18_col0 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# #T_860f8_row18_col1 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_860f8_row18_col2 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_860f8_row18_col3 {
#   background-color: #0570b0;
#   color: #f1f1f1;
# }
# #T_860f8_row18_col4 {
#   background-color: #7eadd1;
#   color: #f1f1f1;
# }
# #T_860f8_row19_col0 {
#   background-color: #89b1d4;
#   color: #000000;
# }
# #T_860f8_row19_col1 {
#   background-color: #0567a1;
#   color: #f1f1f1;
# }
# #T_860f8_row19_col2 {
#   background-color: #045788;
#   color: #f1f1f1;
# }
# #T_860f8_row19_col3, #T_860f8_row23_col3 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_860f8_row19_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_860f8_row20_col0 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_860f8_row20_col1 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_860f8_row20_col2, #T_860f8_row21_col2 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_860f8_row20_col3 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_860f8_row20_col4 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_860f8_row21_col0 {
#   background-color: #e0dded;
#   color: #000000;
# }
# #T_860f8_row21_col1 {
#   background-color: #056caa;
#   color: #f1f1f1;
# }
# #T_860f8_row21_col3 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_860f8_row21_col4 {
#   background-color: #0567a2;
#   color: #f1f1f1;
# }
# #T_860f8_row22_col0 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_860f8_row22_col1 {
#   background-color: #d5d5e8;
#   color: #000000;
# }
# #T_860f8_row22_col2 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_860f8_row22_col3, #T_860f8_row23_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_860f8_row22_col4 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_860f8_row23_col0 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_860f8_row23_col2 {
#   background-color: #cacee5;
#   color: #000000;
# }
# #T_860f8_row23_col4 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_860f8_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_860f8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_860f8_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_860f8_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_860f8_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_860f8_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_860f8_row0_col4" class="data row0 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_860f8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_860f8_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_860f8_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_860f8_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_860f8_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_860f8_row1_col4" class="data row1 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_860f8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_860f8_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_860f8_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_860f8_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_860f8_row2_col3" class="data row2 col3" >0.000000</td>
#       <td

# %% [markdown]
# ## Transformer

# %% [markdown]
# Alright, you know the drill by now.

# %%
xformer = nn.TransformerEncoderLayer(
    d_model=emb_dim,
    nhead=1,
    dim_feedforward=emb_dim,
    batch_first=True)
num_parameters(xformer)
# Out:
# 200

# %%
output = xformer(embeddings)
output.shape
# Out:
# torch.Size([1, 45, 5])

# %%
time_trial(xformer, embeddings)
# Out:
# 1 repetitions of the original sequence, shape = (1, 45, 5)
# 269 µs ± 17.4 µs per loop (mean ± std. dev. of 3 runs, 1000 loops each)
# 2 repetitions of the original sequence, shape = (1, 90, 5)
# 280 µs ± 324 ns per loop (mean ± std. dev. of 3 runs, 1000 loops each)
# 4 repetitions of the original sequence, shape = (1, 180, 5)
# 328 µs ± 752 ns per loop (mean ± std. dev. of 3 runs, 1000 loops each)
# 8 repetitions of the original sequence, shape = (1, 360, 5)
# 384 µs ± 221 ns per loop (mean ± std. dev. of 3 runs, 1000 loops each)
# 16 repetitions of the original sequence, shape = (1, 720, 5)
# 657 µs ± 12.6 µs per loop (mean ± std. dev. of 3 runs, 1000 loops each)

# %%
mask = None
# Then, try this:
# mask = nn.Transformer.generate_square_subsequent_mask(embeddings.shape[-2])

# Recreate the embeddings
embeddings = embedder(input_ids)
embeddings.retain_grad() # Tell Torch we want to know what the gradients are here.
# Pass the embeddings through the model and language modeling head.
output = xformer(embeddings, mask)
logits = lm_head(output)
# Compute the loss
loss = F.cross_entropy(logits.transpose(1, 2), targets, reduction='none')
# Let the model learn from one single character (the one at index 20)
loss[0, 20].backward()
# Show the results
highlight_values(embeddings.grad)
# Out:
# <style type="text/css">
# #T_019dd_row0_col0, #T_019dd_row0_col4, #T_019dd_row1_col0, #T_019dd_row1_col2, #T_019dd_row1_col3, #T_019dd_row1_col4, #T_019dd_row2_col2, #T_019dd_row2_col3, #T_019dd_row2_col4, #T_019dd_row3_col0, #T_019dd_row3_col3, #T_019dd_row4_col0, #T_019dd_row4_col4, #T_019dd_row5_col0, #T_019dd_row5_col4, #T_019dd_row6_col0, #T_019dd_row6_col4, #T_019dd_row7_col0, #T_019dd_row7_col4, #T_019dd_row8_col2, #T_019dd_row8_col3, #T_019dd_row8_col4, #T_019dd_row9_col0, #T_019dd_row9_col3, #T_019dd_row10_col0, #T_019dd_row10_col1, #T_019dd_row11_col0, #T_019dd_row11_col3, #T_019dd_row11_col4, #T_019dd_row12_col0, #T_019dd_row13_col0, #T_019dd_row13_col1, #T_019dd_row14_col0, #T_019dd_row14_col2, #T_019dd_row14_col3, #T_019dd_row15_col0, #T_019dd_row15_col3, #T_019dd_row16_col0, #T_019dd_row16_col4, #T_019dd_row17_col0, #T_019dd_row18_col2, #T_019dd_row18_col3, #T_019dd_row18_col4, #T_019dd_row19_col0, #T_019dd_row19_col3, #T_019dd_row21_col0, #T_019dd_row21_col4, #T_019dd_row22_col0, #T_019dd_row22_col3, #T_019dd_row22_col4, #T_019dd_row23_col0, #T_019dd_row23_col4, #T_019dd_row24_col2, #T_019dd_row24_col3, #T_019dd_row24_col4, #T_019dd_row25_col0, #T_019dd_row25_col2, #T_019dd_row25_col3, #T_019dd_row25_col4, #T_019dd_row26_col0, #T_019dd_row26_col3, #T_019dd_row27_col0, #T_019dd_row28_col0, #T_019dd_row28_col1, #T_019dd_row29_col2, #T_019dd_row29_col3, #T_019dd_row29_col4, #T_019dd_row30_col0, #T_019dd_row30_col3, #T_019dd_row30_col4, #T_019dd_row31_col0, #T_019dd_row31_col3, #T_019dd_row32_col2, #T_019dd_row32_col3, #T_019dd_row32_col4, #T_019dd_row33_col0, #T_019dd_row33_col2, #T_019dd_row33_col3, #T_019dd_row33_col4, #T_019dd_row34_col2, #T_019dd_row34_col3, #T_019dd_row34_col4, #T_019dd_row35_col0, #T_019dd_row35_col3, #T_019dd_row36_col4, #T_019dd_row37_col0, #T_019dd_row37_col2, #T_019dd_row37_col3, #T_019dd_row38_col0, #T_019dd_row38_col3, #T_019dd_row38_col4, #T_019dd_row39_col0, #T_019dd_row39_col3, #T_019dd_row40_col0, #T_019dd_row40_col3, #T_019dd_row41_col0, #T_019dd_row41_col2, #T_019dd_row41_col3, #T_019dd_row41_col4, #T_019dd_row42_col0, #T_019dd_row43_col3, #T_019dd_row43_col4, #T_019dd_row44_col0, #T_019dd_row44_col1, #T_019dd_row44_col4 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T
d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_019dd_row0_col0" class="data row0 col0" >-0.000252</td>
#       <td id="T_019dd_row0_col1" class="data row0 col1" >0.001022</td>
#       <td id="T_019dd_row0_col2" class="data row0 col2" >0.000876</td>
#       <td id="T_019dd_row0_col3" class="data row0 col3" >-0.000047</td>
#       <td id="T_019dd_row0_col4" class="data row0 col4" >-0.001458</td>
#     </tr>
#     <tr>
#       <th id="T_019dd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_019dd_row1_col0" class="data row1 col0" >-0.000187</td>
#       <td id="T_019dd_row1_col1" class="data row1 col1" >0.001984</td>
#       <td id="T_019dd_row1_col2" class="data row1 col2" >-0.000207</td>
#       <td id="T_019dd_row1_col3" class="data row1 col3" >-0.000401</td>
#       <td id="T_019dd_row1_col4" class="data row1 col4" >-0.002174</td>
#     </tr>
#     <tr>
#       <th id="T_019dd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_019dd_row2_col0" class="data row2 col0" >-0.000003</td>
#       <td id="T_019dd_row2_col1" class="data row2 col1" >0.001426</td>
#       <td id="T_019dd_row2_col2" class="data row2 col2" >-0.000975</td>
#       <td id="T_019dd_row2_col3" class="data row2 col3" >-0.000423</td>
#       <td id="T_019dd_row2_col4" class="data row2 col4" >-0.001278</td>
#     </tr>
#     <tr>
#       <th id="T_019dd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_019dd_row3_col0" class="data row3 col0" >-0.000204</td>
#       <td id="T_019dd_row3_col1" class="data row3 col1" >0.007800</td>
#       <td id="T_019dd_row3_col2" class="data row3 col2" >-0.004159</td>
#       <td id="T_019dd_row3_col3" class="data row3 col3" >-0.002122</td>
#       <td id="T_019dd_row3_col4" class="data row3 col4" >-0.007400</td>
#     </tr>
#     <tr>
#       <th id="T_019dd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_019dd_row4_col0" class="data row4 col0" >-0.000203</td>
#       <td id="T_019dd_row4_col1" class="data row4 col1" >0.000371</td>
#       <td id="T_019dd_row4_col2" class="data row4 col2" >0.001025</td>
#       <td id="T_019dd_row4_col3" class="data row4 col3" >0.000098</td>
#       <td id="T_019dd_row4_col4" class="data row4 col4" >-0.000773</td>
#     </tr>
#     <tr>
#       <th id="T_019dd_level0_row5" class="row_heading l

# %% [markdown]
# # Analysis
#
# Q1: Explain the shape of each model's output.

# %% [markdown]
# Feed-Forward:
# GRU:
# Convolution:
# Transformer:

# %% [markdown]
# Q2: Compare the speeds of the models. Which are fastest on short sequences? How does each model's speed change as the sequence length increases?

# %% [markdown]
# Q3: Explain your observations about speed in the previous question by referring to how each model is structured. (i.e., *why* does Conv's speed not change much as the sequence length gets longer?) Think about what operations can happen in parallel.

# %% [markdown]
# Q4: We back-propagated the loss of a single character (the one at index 20) back to the embeddings. If an input token was used as part of making that prediction, its embedding vector will have a non-zero gradient. **Describe which tokens were used when making the prediction for the character at index 20**, for each model.

# %% [markdown]
# Q5: Explain your observations from the previous question by referring to how each model is structured.

# %% [markdown]
# Q6: Which model will most readily learn how the output at index 20 depends on the input at index 1? Explain your answer by referring to the plots of the gradient norms (which is a measure of the strength of that gradient).

# %% [markdown]
# Q7: How many parameters does the `embedder` have? How many parameters does the `lm_head` have? How does this compare with the number of parameters in the model itself? In light of this, why might it make sense to tie the weights of those two modules as we did?
