# %% [markdown]
# # Models for Sequence Data
#
# The goal of this exercise is to explore the structure, speed, and data flow in each of the 4 main kinds of models that are often used for sequence data: feedforward, recurrent (LSTM/GRU), convolutional, and self-attention (Transformer).
#
# This level of knowledge of how each model works should equip you to make wise decisions about when to use each one, without having to get too much into the details of how each one works.

# %% [markdown]
# ## Setup

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

def highlight_values(x):
    """Show a 2D tensor with background highlighted. Also show the norms."""
    x = x.squeeze() # collapse singleton dimensions, like batch.
    assert len(x.shape) == 2, "Can only handle 2D data"
    display(pd.DataFrame(x.numpy()).style.background_gradient(axis=None))
    plt.plot(x.norm(dim=1)); plt.title("Norm on axis 1"); plt.xlabel("Input time step")

def num_parameters(model):
    """Count the number of trainable parameters in a model"""
    return sum(param.numel() for param in model.parameters() if param.requires_grad)

def time_trial(model, embeddings, concat_on_axis=1):
    '''Time how long a forward pass of the model takes on embeddings, varying the sequence length.'''
    for i in range(5):
        num_reps = 2 ** i
        x = torch.cat([embeddings] * num_reps, axis=concat_on_axis)
        print(f'{num_reps} repetitions of the original sequence, shape = {tuple(x.shape)}')
        # %timeit -r 3 model(x)

# %% [markdown]
# ## Getting started
#
# Let's start with an input sequence.

# %%
sentence = "The quick brown fox jumped over the lazy dogs."

# %% [markdown]
# Let's turn it into numbers by using the Unicode code point for each character. We'll make a "batch" of one sequence.

# %%
sentence_tensor = torch.tensor([[ord(x) for x in sentence]])
sentence_tensor
# Out:
# tensor([[ 84, 104, 101,  32, 113, 117, 105,  99, 107,  32,  98, 114, 111, 119,
#          110,  32, 102, 111, 120,  32, 106, 117, 109, 112, 101, 100,  32, 111,
#          118, 101, 114,  32, 116, 104, 101,  32, 108,  97, 122, 121,  32, 100,
#          111, 103, 115,  46]])

# %%
def decode(x):
    return ''.join(chr(x) for x in x.numpy())
decode(sentence_tensor[0])
# Out:
# 'The quick brown fox jumped over the lazy dogs.'

# %% [markdown]
# We'll make this an autoregressive language model, so our goal will be to predict the next character. So we'll need to shift the targets left, so each character should output the next one.

# %%
targets = sentence_tensor[:, 1:]
input_ids = sentence_tensor[:, :-1]
assert input_ids.shape == targets.shape

# %% [markdown]
# Now let's make those numbers into vectors using an embedding. Note that we're just going to use the random initialization right now; we're not yet training this model.

# %%
n_vocab = 256
emb_dim = 5
embedder = nn.Embedding(n_vocab, emb_dim)
embedder.weight.shape
# Out:
# torch.Size([256, 5])

# %%
num_parameters(embedder)
# Out:
# 1280

# %% [markdown]
# Now we compute the embeddings for our string. **Make sure you can explain the shape of this result.**

# %%
embeddings = embedder(input_ids)
embeddings.shape
# Out:
# torch.Size([1, 45, 5])

# %% [markdown]
# Now we'll define the linear layer that goes from embeddings back to words. This is usually called the "language modeling head". We'll *tie the weights* of the LM head with the embedding layer, saving some parameters.

# %%
lm_head = nn.Linear(emb_dim, n_vocab)
assert lm_head.weight.shape == embedder.weight.shape
lm_head.weight = embedder.weight

# %% [markdown]
# Here's what the output of the model will look like. We haven't trained anything yet, though, so the specific numbers will be garbage, but the shape is right and that's most of the battle.

# %%
x = embeddings # pretend that this is the model...
logits = lm_head(x)
logits.shape
# Out:
# torch.Size([1, 45, 256])

# %% [markdown]
# Then we'll compute the cross-entropy loss as usual.
#
# Note: we need to `transpose` the `logits` so that the time steps are on the last dimension, so the last dimensions line up with `targets`. I suspect PyTorch uses this convention because it could extend to 2D `targets` (e.g., images), but I admit I'm not entirely sure why.

# %%
loss = F.cross_entropy(logits.transpose(1, 2), targets, reduction='none')
loss.shape
# Out:
# torch.Size([1, 45])

# %% [markdown]
# ## Feed-Forward Network

# %% [markdown]
# Here's the simplest model we can make: a multi-layer perceptron. Fill in the blanks here so our model has *one hidden layer* with a *relu activation* (`nn.ReLU`).
#
# - The output should have the same dimensionality as the embeddings
# - Set `n_hidden` to a small integer, so that there are about 180 parameters.

# %% [markdown]
# ### Create the model

# %%
n_hidden = 16 # increased starting at 10 until output was 181
mlp = nn.Sequential(
    nn.Linear(in_features=emb_dim, out_features=n_hidden),
    nn.ReLU(),
    nn.Linear(in_features=n_hidden, out_features=emb_dim)
)

num_parameters(mlp)
# Out:
# 181

# %% [markdown]
# ### Check its output shape

# %%
output = mlp(embeddings)
assert output.shape == (1, 45, 5)
output.shape
# Out:
# torch.Size([1, 45, 5])

# %% [markdown]
# ### Check its speed

# %%
time_trial(mlp, embeddings)
# Out:
# 1 repetitions of the original sequence, shape = (1, 45, 5)
# 29.7 µs ± 106 ns per loop (mean ± std. dev. of 3 runs, 10000 loops each)
# 2 repetitions of the original sequence, shape = (1, 90, 5)
# 30.1 µs ± 149 ns per loop (mean ± std. dev. of 3 runs, 10000 loops each)
# 4 repetitions of the original sequence, shape = (1, 180, 5)
# 32.4 µs ± 163 ns per loop (mean ± std. dev. of 3 runs, 10000 loops each)
# 8 repetitions of the original sequence, shape = (1, 360, 5)
# 35.9 µs ± 114 ns per loop (mean ± std. dev. of 3 runs, 10000 loops each)
# 16 repetitions of the original sequence, shape = (1, 720, 5)
# 42.7 µs ± 64.7 ns per loop (mean ± std. dev. of 3 runs, 10000 loops each)

# %% [markdown]
# ### Check how gradients flow

# %%
# Recreate the embeddings
embeddings = embedder(input_ids)
embeddings.retain_grad() # Tell Torch we want to know what the gradients are here.
# Pass the embeddings through the model and language modeling head.
output = mlp(embeddings)
logits = lm_head(output)
# Compute the loss
loss = F.cross_entropy(logits.transpose(1, 2), targets, reduction='none')
# Let the model learn from one single character (the one at index 20)
loss[0, 20].backward()
# Show the results
highlight_values(embeddings.grad)
# Out:
# <style type="text/css">
# #T_efc26_row0_col0, #T_efc26_row0_col1, #T_efc26_row0_col2, #T_efc26_row0_col3, #T_efc26_row0_col4, #T_efc26_row1_col0, #T_efc26_row1_col1, #T_efc26_row1_col2, #T_efc26_row1_col3, #T_efc26_row1_col4, #T_efc26_row2_col0, #T_efc26_row2_col1, #T_efc26_row2_col2, #T_efc26_row2_col3, #T_efc26_row2_col4, #T_efc26_row3_col0, #T_efc26_row3_col1, #T_efc26_row3_col2, #T_efc26_row3_col3, #T_efc26_row3_col4, #T_efc26_row4_col0, #T_efc26_row4_col1, #T_efc26_row4_col2, #T_efc26_row4_col3, #T_efc26_row4_col4, #T_efc26_row5_col0, #T_efc26_row5_col1, #T_efc26_row5_col2, #T_efc26_row5_col3, #T_efc26_row5_col4, #T_efc26_row6_col0, #T_efc26_row6_col1, #T_efc26_row6_col2, #T_efc26_row6_col3, #T_efc26_row6_col4, #T_efc26_row7_col0, #T_efc26_row7_col1, #T_efc26_row7_col2, #T_efc26_row7_col3, #T_efc26_row7_col4, #T_efc26_row8_col0, #T_efc26_row8_col1, #T_efc26_row8_col2, #T_efc26_row8_col3, #T_efc26_row8_col4, #T_efc26_row9_col0, #T_efc26_row9_col1, #T_efc26_row9_col2, #T_efc26_row9_col3, #T_efc26_row9_col4, #T_efc26_row10_col0, #T_efc26_row10_col1, #T_efc26_row10_col2, #T_efc26_row10_col3, #T_efc26_row10_col4, #T_efc26_row11_col0, #T_efc26_row11_col1, #T_efc26_row11_col2, #T_efc26_row11_col3, #T_efc26_row11_col4, #T_efc26_row12_col0,
#   background-color: #67a4cc;
#   color: #f1f1f1;
# }
# #T_efc26_row20_col0 {
#   background-color: #045280;
#   color: #f1f1f1;
# }
# #T_efc26_row20_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_efc26_row20_col2 {
#   background-color: #03456c;
#   color: #f1f1f1;
# }
# #T_efc26_row20_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_efc26_row20_col4 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_efc26_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_efc26_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_efc26_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_efc26_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_efc26_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_efc26_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_efc26_row0_col4" class="data row0 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_efc26_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_efc26_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_efc26_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_efc26_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_efc26_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_efc26_row1_col4" class="data row1 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_efc26_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_efc26_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_efc26_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_efc26_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_efc26_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_efc26_row2_col4" class="data row2 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_efc26_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_efc26_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_efc26_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_efc26_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_efc26_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_efc26_row3_col4" class="data row3 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_efc26_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_efc26_row4_col0" class="data row4 col0" >0.000000</td>
#       <td id="T_efc26_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_efc26_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_efc26_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_efc26_row4_col4" class="data row4 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_efc26_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_efc26_row5_col0" class="data row5 col0" >0.000000</td>
#       <td id="T_efc26_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_efc26_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_efc26_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id=

# %% [markdown]
# ## GRU

# %%
gru = nn.GRU(emb_dim, emb_dim, batch_first=True)
num_parameters(gru)
# Out:
# 180

# %%
output, hidden = gru(embeddings)
output.shape, hidden.shape
# Out:
# (torch.Size([1, 45, 5]), torch.Size([1, 1, 5]))

# %% [markdown]
# Note that `hidden` is just another name for the output at the last state (since GRU is simple).

# %%
(output[:, -1, :] == hidden).all()
# Out:
# tensor(True)

# %% [markdown]
# ### Your turn
#
# 1. Repeat the time trial, but for `gru` this time.

# %%
time_trial(gru, embeddings)
# Out:
# 1 repetitions of the original sequence, shape = (1, 45, 5)
# 1.15 ms ± 3.74 µs per loop (mean ± std. dev. of 3 runs, 1000 loops each)
# 2 repetitions of the original sequence, shape = (1, 90, 5)
# 2.29 ms ± 22.1 µs per loop (mean ± std. dev. of 3 runs, 100 loops each)
# 4 repetitions of the original sequence, shape = (1, 180, 5)
# 4.34 ms ± 36.8 µs per loop (mean ± std. dev. of 3 runs, 100 loops each)
# 8 repetitions of the original sequence, shape = (1, 360, 5)
# 8.6 ms ± 6.85 µs per loop (mean ± std. dev. of 3 runs, 100 loops each)
# 16 repetitions of the original sequence, shape = (1, 720, 5)
# 18 ms ± 20.5 µs per loop (mean ± std. dev. of 3 runs, 100 loops each)

# %% [markdown]
# 2. Repeat the gradient-flow experiment by copy-pasting the code above and changing the model. Remember that `gru` returns `output, hidden`, unlike the other models.

# %%
# Recreate the embeddings
embeddings = embedder(input_ids)
embeddings.retain_grad() # Tell Torch we want to know what the gradients are here.
# Pass the embeddings through the model and language modeling head.
output, hidden = gru(embeddings)
logits = lm_head(output)
# Compute the loss
loss = F.cross_entropy(logits.transpose(1, 2), targets, reduction='none')
# Let the model learn from one single character (the one at index 20)
loss[0, 20].backward()
# Show the results
highlight_values(embeddings.grad)
# Out:
# <style type="text/css">
# #T_d3127_row0_col0, #T_d3127_row0_col1, #T_d3127_row0_col2, #T_d3127_row0_col3, #T_d3127_row0_col4, #T_d3127_row1_col0, #T_d3127_row1_col1, #T_d3127_row1_col2, #T_d3127_row1_col3, #T_d3127_row1_col4, #T_d3127_row2_col0, #T_d3127_row2_col1, #T_d3127_row2_col2, #T_d3127_row2_col3, #T_d3127_row2_col4, #T_d3127_row3_col0, #T_d3127_row3_col1, #T_d3127_row3_col2, #T_d3127_row3_col3, #T_d3127_row3_col4, #T_d3127_row4_col0, #T_d3127_row4_col1, #T_d3127_row4_col2, #T_d3127_row4_col3, #T_d3127_row4_col4, #T_d3127_row5_col0, #T_d3127_row5_col1, #T_d3127_row5_col2, #T_d3127_row5_col3, #T_d3127_row5_col4, #T_d3127_row6_col0, #T_d3127_row6_col1, #T_d3127_row6_col2, #T_d3127_row6_col3, #T_d3127_row6_col4, #T_d3127_row7_col0, #T_d3127_row7_col1, #T_d3127_row7_col2, #T_d3127_row7_col3, #T_d3127_row7_col4, #T_d3127_row8_col0, #T_d3127_row8_col1, #T_d3127_row8_col2, #T_d3127_row8_col3, #T_d3127_row8_col4, #T_d3127_row9_col0, #T_d3127_row9_col1, #T_d3127_row9_col2, #T_d3127_row9_col3, #T_d3127_row9
_d3127_row38_col3, #T_d3127_row38_col4, #T_d3127_row39_col0, #T_d3127_row39_col1, #T_d3127_row39_col2, #T_d3127_row39_col3, #T_d3127_row39_col4, #T_d3127_row40_col0, #T_d3127_row40_col1, #T_d3127_row40_col2, #T_d3127_row40_col3, #T_d3127_row40_col4, #T_d3127_row41_col0, #T_d3127_row41_col1, #T_d3127_row41_col2, #T_d3127_row41_col3, #T_d3127_row41_col4, #T_d3127_row42_col0, #T_d3127_row42_col1, #T_d3127_row42_col2, #T_d3127_row42_col ...
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_d3127_row14_col0, #T_d3127_row15_col0, #T_d3127_row16_col0, #T_d3127_row16_col2, #T_d3127_row17_col0 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_d3127_row16_col4, #T_d3127_row17_col3 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_d3127_row18_col0, #T_d3127_row19_col3 {
#   background-color: #a9bfdc;
#   color: #000000;
# }
# #T_d3127_row18_col1, #T_d3127_row19_col1 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_d3127_row18_col2 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_d3127_row18_col4 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_d3127_row19_col0 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_d3127_row19_col2 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_d3127_row19_col4 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_d3127_row20_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_d3127_row20_col1 {
#   background-color: #86b0d3;
#   color: #000000;
# }
# #T_d3127_row20_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d3127_row20_col3 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_d3127_row20_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d3127_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3127_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d3127_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_d3127_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_d3127_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_d3127_row0_col3" class="data row0 col3" >-0.000000</td>
#       <td id="T_d3127_row0_col4" class="data row0 col4" >-0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d3127_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d3127_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_d3127_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_d3127_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_d3127_row1_col3" class="data row1 col3" >-0.000000</td>
#       <td id="T_d3127_row1_col4" class="data row1 col4" >-0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d3127_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d3127_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_d3127_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_d3127_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_d3127_row2_col3" class="data row2 col3" >-0.000000</td>
#       <td id="T_d3127_row2_col4" class="data row2 col4" >-0.000001</td>
#     </tr>
#     <tr>
#       <th id="T_d3127_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d3127_row3_col0" class="data row3 col0" >0.000001</td>
#       <td id="T_d3127_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_d3127_row3_col2" class="data row3 col2" >0.000001</td>
#       <td id="T_d3127_row3_col3" class="data row3 col3" >-0.000000</td>
#       <td id="T_d3127_row3_col4" class="data row3 col4" >-0.000001</td>
#     </tr>
#     <tr>
#       <th id="T_d3127_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d3127_row4_col0" class="data row4 col0" >0.000001</td>
#       <td id="T_d3127_row4_col1" class="data row4 col1" >0.000001</td>
#       <td id="T_d3127_row4_col2" class="data row4 col2" >0.000001</td>
#       <td id="T_d3127_row4_col3" class="data row4 col3" >-0.000001</td>

# %% [markdown]
# ## Convolution

# %% [markdown]
# Now let's make a convolutional network. We'll pick a "kernel size" (how wide a window for each sample to look) so that the total number of parameters matches our previous models. We also need to pad the result so that the output length is the same as the input length; the outputs near the edges won't be valid outputs, though.

# %%
conv = nn.Conv1d(emb_dim, emb_dim, kernel_size=7, padding=3)
num_parameters(conv)
# Out:
# 180

# %% [markdown]
# Unfortunately Conv expects its inputs to be (batch size, *channel*, sequence length), where they think of embedding dimensions as being "channels" -- confusing. Fortunately, this is easily solved by a `transpose` before and after the conv. (not to be confused with "transposed convolution", which is something different.)

# %%
embeddings_for_conv = embeddings.transpose(1, 2)
embeddings_for_conv.shape
# Out:
# torch.Size([1, 5, 45])

# %%
output = conv(embeddings.transpose(1, 2)).transpose(1, 2)
output.shape
# Out:
# torch.Size([1, 45, 5])

# %% [markdown]
# The fact that we had to transpose the embeddings means that we need to tweak `time_trial` to tell it which dimension is the sequence dimension.

# %%
time_trial(conv, embeddings_for_conv, concat_on_axis=2)
# Out:
# 1 repetitions of the original sequence, shape = (1, 5, 45)
# 18.6 µs ± 17 ns per loop (mean ± std. dev. of 3 runs, 100000 loops each)
# 2 repetitions of the original sequence, shape = (1, 5, 90)
# 19.6 µs ± 106 ns per loop (mean ± std. dev. of 3 runs, 100000 loops each)
# 4 repetitions of the original sequence, shape = (1, 5, 180)
# 20.4 µs ± 40.6 ns per loop (mean ± std. dev. of 3 runs, 10000 loops each)
# 8 repetitions of the original sequence, shape = (1, 5, 360)
# 22.6 µs ± 256 ns per loop (mean ± std. dev. of 3 runs, 10000 loops each)
# 16 repetitions of the original sequence, shape = (1, 5, 720)
# 25.8 µs ± 34.3 ns per loop (mean ± std. dev. of 3 runs, 10000 loops each)

# %% [markdown]
# **Your turn**: Repeat the gradient-flow experiment. Make sure you compute `output` as we did above so that the shape is correct.

# %%
# Recreate the embeddings
embeddings = embedder(input_ids)
embeddings.retain_grad() # Tell Torch we want to know what the gradients are here.
# Pass the embeddings through the model and language modeling head.
output = conv(embeddings.transpose(1,2)).transpose(1,2)
logits = lm_head(output)
# Compute the loss
loss = F.cross_entropy(logits.transpose(1, 2), targets, reduction='none')
# Let the model learn from one single character (the one at index 20)
loss[0, 20].backward()
# Show the results
highlight_values(embeddings.grad)
# Out:
# <style type="text/css">
# #T_d6793_row0_col0, #T_d6793_row0_col1, #T_d6793_row0_col2, #T_d6793_row0_col3, #T_d6793_row0_col4, #T_d6793_row1_col0, #T_d6793_row1_col1, #T_d6793_row1_col2, #T_d6793_row1_col3, #T_d6793_row1_col4, #T_d6793_row2_col0, #T_d6793_row2_col1, #T_d6793_row2_col2, #T_d6793_row2_col3, #T_d6793_row2_col4, #T_d6793_row3_col0, #T_d6793_row3_col1, #T_d6793_row3_col2, #T_d6793_row3_col3, #T_d6793_row3_col4, #T_d6793_row4_col0, #T_d6793_row4_col1, #T_d6793_row4_col2, #T_d6793_row4_col3, #T_d6793_row4_col4, #T_d6793_row5_col0, #T_d6793_row5_col1, #T_d6793_row5_col2, #T_d6793_row5_col3, #T_d6793_row5_col4, #T_d6793_row6_col0, #T_d6793_row6_col1, #T_d6793_row6_col2, #T_d6793_row6_col3, #T_d6793_row6_col4, #T_d6793_row7_col0, #T_d6793_row7_col1, #T_d6793_row7_col2, #T_d6793_row7_col3, #T_d6793_row7_col4, #T_d6793_row8_col0, #T_d6793_row8_col1, #T_d6793_row8_col2, #T_d6793_row8_col3, #T_d6793_row8_col4, #T_d6793_row9_col0, #T_d6793_row9_col1, #T_d6793_row9_col2, #T_d6793_row9_col3, #T_d6793_row9_col4, #T_d6793_row10_col0, #T_d6793_row10_col1, #T_d6793_row10_col2, #T_d6793_row10_col3, #T_d6793_row10_col4, #T_d6793_row11_col0, #T_d6793_row11_col1, #T_d6793_row11_col2, #T_d6793_row11_col3, #T_d6793_row11_col4, #T_d6793_row12_col0, #T_d6793_row12_col1, #T_d6793_row12_col2, #T_d6793_row12_col3, #T_d6793_row12_col4, #T_d6793_row13_col0, #T_d6793_row13_col1, #T_d6793_row13_col2, #T_d6793_row13_col3, #T_d6793_row13_col4, #T_d6793_row14_col0, #T_d6793_row14_col1, #T_d6793_row14_col2, #T_d6793_row14_col3, #T_d6793_row14_col4, #T_d6793_row15_col0, #T_d6793_row15_col1, #T_d6793_row15_col2, #T_d6793_row15_col3, #T_d6793_row15_col4, #T_d6793_row16_col0, #T_d6793_row16_col1, #T_d6793_row16_col2, #T_d6793_row16_col3, #T_d6793_row16_col4, #T_d6793_row24_col0, #T_d6793_row24_col1, #T_d6793_row24_col2, #T_d6793_row24_col3, #T_d6793_row24_col4, #T_d6793_row25_col0, #T_d6793_row25_col1, #T_d6793_row25_col2, #T_d6793_row25_col3, #T_d6793_row25_col4, #T_d6793_row26_col0, #T_d6793_row26_col1, #T_d6793_row26_col2, #T_d6793_row26_col3, #T_d6793_row26_col4, #T_d6793_row27_col0, #T_d6793_row27_col1, #T_d6793_row27_col2, #T_d6793_row27_col3, #T_d6793_row
row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_d6793_row2_col2" class="data row2 co

# %% [markdown]
# ## Transformer

# %% [markdown]
# Alright, you know the drill by now.

# %%
xformer = nn.TransformerEncoderLayer(
    d_model=emb_dim,
    nhead=1,
    dim_feedforward=emb_dim,
    batch_first=True)
num_parameters(xformer)
# Out:
# 200

# %%
output = xformer(embeddings)
output.shape
# Out:
# torch.Size([1, 45, 5])

# %%
time_trial(xformer, embeddings)
# Out:
# 1 repetitions of the original sequence, shape = (1, 45, 5)
# 256 µs ± 2.05 µs per loop (mean ± std. dev. of 3 runs, 1000 loops each)
# 2 repetitions of the original sequence, shape = (1, 90, 5)
# 319 µs ± 2.1 µs per loop (mean ± std. dev. of 3 runs, 1000 loops each)
# 4 repetitions of the original sequence, shape = (1, 180, 5)
# 375 µs ± 6.56 µs per loop (mean ± std. dev. of 3 runs, 1000 loops each)
# 8 repetitions of the original sequence, shape = (1, 360, 5)
# 437 µs ± 1.63 µs per loop (mean ± std. dev. of 3 runs, 1000 loops each)
# 16 repetitions of the original sequence, shape = (1, 720, 5)
# 1.27 ms ± 22.1 µs per loop (mean ± std. dev. of 3 runs, 1000 loops each)

# %%
mask = None
# Then, try this:
# mask = nn.Transformer.generate_square_subsequent_mask(embeddings.shape[-2])

# Recreate the embeddings
embeddings = embedder(input_ids)
embeddings.retain_grad() # Tell Torch we want to know what the gradients are here.
# Pass the embeddings through the model and language modeling head.
output = xformer(embeddings, mask)
logits = lm_head(output)
# Compute the loss
loss = F.cross_entropy(logits.transpose(1, 2), targets, reduction='none')
# Let the model learn from one single character (the one at index 20)
loss[0, 20].backward()
# Show the results
highlight_values(embeddings.grad)
# Out:
# <style type="text/css">
# #T_ada8d_row0_col0, #T_ada8d_row1_col1, #T_ada8d_row3_col0, #T_ada8d_row3_col2, #T_ada8d_row5_col1, #T_ada8d_row6_col1, #T_ada8d_row9_col0, #T_ada8d_row9_col2, #T_ada8d_row10_col1, #T_ada8d_row11_col0, #T_ada8d_row11_col1, #T_ada8d_row12_col0, #T_ada8d_row12_col2, #T_ada8d_row15_col0, #T_ada8d_row15_col2, #T_ada8d_row17_col0, #T_ada8d_row17_col2, #T_ada8d_row18_col0, #T_ada8d_row19_col0, #T_ada8d_row19_col2, #T_ada8d_row21_col1, #T_ada8d_row23_col2, #T_ada8d_row25_col0, #T_ada8d_row25_col1, #T_ada8d_row26_col0, #T_ada8d_row26_col2, #T_ada8d_row27_col0, #T_ada8d_row27_col2, #T_ada8d_row30_col0, #T_ada8d_row30_col1, #T_ada8d_row31_col0, #T_ada8d_row31_col2, #T_ada8d_row32_col1, #T_ada8d_row33_col1, #T_ada8d_row35_col0, #T_ada8d_row35_col2, #T_ada8d_row37_col0, #T_ada8d_row37_col1, #T_ada8d_row38_col1, #T_ada8d_row39_col2, #T_ada8d_row40_col0, #T_ada8d_row40_col2, #T_ada8d_row41_col0, #T_ada8d_row41_col1, #T_ada8d_row44_col1 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_ada8d_row0_col1, #T_ada8d_row0_col2, #T_ada8d_row0_col3, #T_ada8d_row1_col0, #T_ada8d_row1_col2, #T_ada8d_row2_col0, #T_ada8d_row2_col1, #T_ada8d_row2_col2, #T_ada8d_row2_col3, #T_ada8d_row3_col3, #T_ada8d_row4_col0, #T_ada8d_row4_col1, #T_ada8d_row4_col2, #T_ada8d_row4_col3, #T_ada8d_row5_col0, #T_ada8d_row5_col2, #T_ada8d_row6_col0, #T_ada8d_row6_col2, #T_ada8d_row7_col0, #T_ada8d_row7_col1, #T_ada8d_row8_col0, #T_ada8d_row8_col1
, #T_ada8d_row29_col4, #T_ada8d_row30_col4, #T_ada8d_row31_col4, #T_ada8d_row32_col3, #T_ada8d_row32_col4, #T_ada8d_row33_col3, #T_ada8d_row33_col4, #T_ada8d_row34_col4, #T_ada8d_row35_col4, #T_ada8d_row36_col4, #T_ada8d_row37_col4, #T_ada8d_row38_col3, #T_ada8d_row38_col4, #T_ada8d_row39_col3, #T_ada8d_row39_col4, #T_ada8d_row40_col4, #T_ada8d_row41_col4, #T_ada8d_row42_col1, #T_ada8d_row42_col2, #T_ada8d_row42_col3, #T_ada8d_row42_col4, #T_ada8d_row43_col3, #T_ada8d_row43_col4, #T_ada8d_row44_col3, #T_ada8d_row44_col4 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_ada8d_row3_col1, #T_ada8d_row9_col1, #T_ada8d_row12_col1, #T_ada8d_row15_col1, #T_ada8d_row17_col1, #T_ada8d_row19_col1, #T_ada8d_row23_col0, #T_ada8d_row26_col1, #T_ada8d_row27_col1, #T_ada8d_row31_col1, #T_ada8d_row35_col1, #T_ada8d_row39_col1, #T_ada8d_row40_col1 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_ada8d_row20_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_ada8d_row20_col1 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_ada8d_row20_col2 {
#   background-color: #e6e2ef;
#   color: #000000;
# }
# #T_ada8d_row20_col3 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_ada8d_row20_col4 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ada8d_row23_col1 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# </style>
# <table id="T_ada8d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ada8d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ada8d_row0_col0" class="data row0 col0" >0.012264</td>
#       <td id="T_ada8d_row0_col1" class="data row0 col1" >0.008802</td>
#       <td id="T_ada8d_row0_col2" class="data row0 col2" >0.004293</td>
#       <td id="T_ada8d_row0_col3" class="data row0 col3" >0.002070</td>
#       <td id="T_ada8d_row0_col4" class="data row0 col4" >-0.002007</td>
#     </tr>
#     <tr>
#       <th id="T_ada8d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ada8d_row1_col0" class="data row1 col0" >0.005640</td>
#       <td id="T_ada8d_row1_col1" class="data row1 col1" >0.012376</td>
#       <td id="T_ada8d_row1_col2" class="data row1 col2" >0.005571</td>
#       <td id="T_ada8d_row1_col3" class="data row1 col3" >0.000122</td>
#       <td id="T_ada8d_row1_col4" class="data row1 col4" >-0.002644</td>
#     </tr>
#     <tr>
#       <th id="T_ada8d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ada8d_row2_col0" class="data row2 col0" >0.005672</td>
#       <td id="T_ada8d_row2_col1" class="data row2 col1" >0.002605</td>
#       <td id="T_ada8d_row2_col2" class="data row2 col2" >0.001352</td>
#       <td id="T_ada8d_row2_col3" class="data row2 col3" >0.001103</td>
#       <td id="T_ada8d_row2_col4" class="data row2 col4" >-0.000625</td>
#     </tr>
#     <tr>
#       <th id="T_ada8d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ada8d_row3_col0" class="data row3 col0" >0.015085</td>
#       <td id="T_ada8d_row3_col1" class="data row3 col1" >0.026651</td>
#       <td id="T_ada8d_row3_col2" class="data row3 col2" >0.012115</td>
#       <td id="T_ada8d_row3_col3" class="data row3 col3" >0.000969</td>
#       <td id="T_ada8d_row3_col4" class="data row3 col4" >-0.005739</td>
#     </tr>
#     <tr>
#       <th id="T_ada8d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ada8d_row4_col0" class="data row4 col0" >0.007722</td>
#       <td id="T_ada8d_row4_col1" class="data row4 col1" >0.008401</td>
#       <td id="T_ada8d_row4_col2" class="data row4 col2" >0.003938</td>
#       <td id="T_ada8d_row4_col3" class="data row4 col3" >0.001018</td>
#       <td id="T_ada8d_row4_col4" class="data row4 col4" >-0.001854</td>
#     </tr>
#     <tr>
#       <th id="T_ada8d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ada8d_row5_col0" class="data row5 col0" >0.005606</td>
#       <td id="T_ada8d

# %% [markdown]
# # Analysis
#
# Q1: Explain the shape of each model's output.

# %% [markdown]
# Feed-Forward: [1, 45, 5] --> [batch size, number of tokens, embedding number]
# GRU: output.shape = [1, 45, 5] --> [batch size, number of tokens, embedding dimension], hidden.shape = [1, 1, 5] --> [batch size, number of hiddens, embedding dimension]
# Convolution: [1, 5, 45] --> [batch size, channels/embedding dimension, number of tokens], output is transposed
# Transformer: [1, 45, 5] --> [batch size, number of tokens, embedding dimension]

# %% [markdown]
# Q2: Compare the speeds of the models. Which are fastest on short sequences? How does each model's speed change as the sequence length increases?

# %% [markdown]
# The convolution model is the fastest on short sequences. As the sequence length increases, the model's speed descreases, but by the least out of all the models. The feed-forward network increases slowly with each added repetition, much like the convolution model, only with a slower speed overall. The transformer model speed increases by about 10 times the number of repetitions added to the sequence length. The GRU model is the slowest and increases by 1 ms for every repetition added to the sequence.

# %% [markdown]
# Q3: Explain your observations about speed in the previous question by referring to how each model is structured. (i.e., *why* does Conv's speed not change much as the sequence length gets longer?) Think about what operations can happen in parallel.

# %% [markdown]
# While none of Feed-Forward's processing happens in parallel, it is still fast because it is simple and can only process in one direction.
# GRU's speed is slow because is includes a hidden state for each sample of the sequence that is uses.
# Convolution's speed does not increase much as the sequence increases because the model is simultaneously looking at adjacent samples of the sequence. Increasing the length of the sequence means adding more samples, which are still analyzed in parallel.
# Transformer's speed increases as the sequence gets longer because adding more samples means adding more queries, keys, and values to the computation time. However, because this happens in parallel, the speed does not increase dramatically.

# %% [markdown]
# Q4: We back-propagated the loss of a single character (the one at index 20) back to the embeddings. If an input token was used as part of making that prediction, its embedding vector will have a non-zero gradient. **Describe which tokens were used when making the prediction for the character at index 20**, for each model.

# %% [markdown]
# Feed-Forward: only uses tokens at index 20
# GRU: uses all tokens leading up to index 20, but none after
# Convolution: uses tokens from 3 indices before before and after index 20
# Transformer: uses all tokens available

# %% [markdown]
# Q5: Explain your observations from the previous question by referring to how each model is structured.

# %% [markdown]
# Feed-forward only uses tokens at the prediciton index because it only has one layer to go through.
# GRU uses the previous token for predicting the next token to come and uses that sequencing until getting to the prediction index.
# Convolution's structure looks at a set group of samples from the sequence based on the position of the prediction index.
# Transformer puts all the possible tokens into one mega mixing matrix and uses all the computed queries and keys to create the prediction for the given index.

# %% [markdown]
# Q6: Which model will most readily learn how the output at index 20 depends on the input at index 1? Explain your answer by referring to the plots of the gradient norms (which is a measure of the strength of that gradient).

# %% [markdown]
# By the gradients flow, transformers would most readily learn how to output at indeax 20 based on input at index 1, which follows its structure where all the tokens available at every idex are put into one mega mixing matrix.

# %% [markdown]
# Q7: How many parameters does the `embedder` have? How many parameters does the `lm_head` have? How does this compare with the number of parameters in the model itself? In light of this, why might it make sense to tie the weights of those two modules as we did?

# %% [markdown]
# embedder has 1280 parameters. lm_head has 1536 parameters.
# The models have three parameters.
# Tying the weights of embedder and lm_head together makes sense since they both have weights for embedding size and vocabulary size.

# %%
num_parameters(lm_head)
# Out:
# 1536
